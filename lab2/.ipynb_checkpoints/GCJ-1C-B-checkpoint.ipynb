# %%
import random
from time import time
random.seed(time())

# %%
U = 15
N = pow(10, U)-1

n = 10000

#print(N)
tc = []

for T in range(n):
    mi = random.randint(1, N)
    ri = random.randint(1, mi)
    tc.append(ri)

# %%
tc
# Out:
# [95606904557118,
#  262081651282886,
#  374045241502553,
#  49166728835147,
#  65980380044478,
#  226653121796675,
#  130012140933102,
#  530729332367747,
#  820419753556946,
#  131178859346477,
#  505925992443904,
#  574659077477500,
#  24571875252614,
#  749683884606199,
#  96789366136784,
#  24888582283580,
#  108403190976940,
#  380273650438323,
#  432738690333927,
#  9838545318876,
#  26331329444877,
#  919870548749926,
#  130639287393,
#  68895447090484,
#  11310313698371,
#  18852123812254,
#  260559400288685,
#  111045294995759,
#  109168820677760,
#  310753554184268,
#  184652325834216,
#  216304362733025,
#  247144102919502,
#  75228143640283,
#  350599485992230,
#  48367611317376,
#  345856637836453,
#  828795593970415,
#  204692151945412,
#  177464531299721,
#  276679361465083,
#  339591586659404,
#  380212204241905,
#  85701102004678,
#  260484308840756,
#  76060596725272,
#  905437885838516,
#  331066878333,
#  262929939165011,
#  281421678020630,
#  192310842103980,
# ...

# %%
for i in range()
